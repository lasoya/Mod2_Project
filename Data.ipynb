# %%
import pandas as pd

# %% [markdown]
# ## Overall USDA Mangos Import Data - Unit Price

# %%
# read in the mango USDA import unit price data and assign to a variable
unit_price = pd.read_excel('./data/Mangos_USDA_Data.xlsx', sheet_name = 'ImpUnitVal', header = 5)

# %%
unit_price.head()
# Out:
#    Unnamed: 0 Dried   NaN Market year*      Jan      Feb      Mar       Q1  \
# 0         NaN  None  None         2018   4.1689  4.67385  4.42561  4.40594
# 1         NaN  None  None         2017  5.13276  4.21988  4.51251   4.5771
# 2         NaN  None  None         2016  4.42959   4.3286  4.80279  4.57827
# 3         NaN  None  None         2015  4.23784  4.18233  4.00886   4.1291
# 4         NaN  None  None         2014  4.59758  4.28765  3.87335  4.33069
#
#        Apr      May  ...       Q2      Jul      Aug      Sep       Q3  \
# 0  4.18748  4.23262  ...  4.14876  4.14522  4.00654  3.97254  4.04212
# 1  4.56652  4.20651  ...  4.27253  4.35839  4.06075   3.9918  4.14622
# 2  4.47377  4.31368  ...  4.39862  4.14031  4.35618  4.32316    4.283
# 3  4.35502  4.08396  ...  4.20001  4.41836  4.48078   4.3286  4.42496
# 4  4.77958  3.88614  ...  4.32473  4.27625  4.28681   4.1391  4.24435
#
#        Oct      Nov      Dec       Q4      Avg
# ...

# %%
unit_price.tail()
# Out:
#     Unnamed: 0 Dried                                                NaN  \
# 52         NaN  None                                               None
# 53         NaN  None                                               None
# 54         NaN  None                                               None
# 55         NaN  None                                               None
# 56         NaN  None  Unit value calculated by dividing value by vol...
#
#    Market year*       Jan       Feb       Mar        Q1       Apr       May  \
# 52         2010  0.600559  0.577899   0.65163  0.612586  0.618305  0.630983
# 53         2009  0.670995  0.589122  0.547563   0.59344  0.620059  0.581828
# 54         None      None      None      None      None      None      None
# 55         None      None      None      None      None      None      None
# 56         None      None      None      None      None      None      None
#
# ...

# %%
unit_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 23 columns):
# Unnamed: 0      0 non-null float64
# Dried           4 non-null object
# None            1 non-null object
# Market year*    54 non-null object
# Jan             51 non-null object
# Feb             51 non-null object
# Mar             51 non-null object
# Q1              51 non-null object
# Apr             51 non-null object
# May             51 non-null object
# None.1          0 non-null float64
# None.2          0 non-null float64
# Jun             51 non-null object
# Q2              51 non-null object
# Jul             52 non-null object
# Aug             52 non-null object
# Sep             52 non-null object
# Q3              52 non-null object
# Oct             52 non-null object
# Nov             52 non-null object
# Dec             52 non-null object
# Q4              52 non-null object
# Avg             52 non-null object
# dtypes: float64(3), object(20)
# ...

# %%
# drop unnecessary columns
unit_price = unit_price.drop(['Unnamed: 0', 'Dried', None, 'None.1', 'None.2'], axis=1)

# %%
unit_price.head()
# Out:
#   Market year*      Jan      Feb      Mar       Q1      Apr      May      Jun  \
# 0         2018   4.1689  4.67385  4.42561  4.40594  4.18748  4.23262  4.03364
# 1         2017  5.13276  4.21988  4.51251   4.5771  4.56652  4.20651  4.16924
# 2         2016  4.42959   4.3286  4.80279  4.57827  4.47377  4.31368  4.42149
# 3         2015  4.23784  4.18233  4.00886   4.1291  4.35502  4.08396  4.15906
# 4         2014  4.59758  4.28765  3.87335  4.33069  4.77958  3.88614   4.2399
#
#         Q2      Jul      Aug      Sep       Q3      Oct      Nov      Dec  \
# 0  4.14876  4.14522  4.00654  3.97254  4.04212  4.01016  4.49586  3.92103
# 1  4.27253  4.35839  4.06075   3.9918  4.14622  3.91572  4.01106  4.75184
# 2  4.39862  4.14031  4.35618  4.32316    4.283  3.98047  4.31424  4.66212
# 3  4.20001  4.41836  4.48078   4.3286  4.42496  3.83202   3.8038  4.19684
# 4  4.32473  4.27625  4.28681   4.1391  4.24435  3.95973  3.34679  3.72584
#
#         Q4      Avg
# 0  4.14612  4.14782
# ...

# %%
unit_price['Market year*'].value_counts()
# Out:
# 2016            5
# 2014            5
# 2013            5
# 2011            5
# 2009            5
# 2017            5
# 2015            5
# 2010            5
# 2012            5
# 2018            5
# Market year*    4
# Name: Market year*, dtype: int64

# %%
unit_price
# Out:
#     Market year*       Jan       Feb       Mar        Q1       Apr       May  \
# 0           2018    4.1689   4.67385   4.42561   4.40594   4.18748   4.23262
# 1           2017   5.13276   4.21988   4.51251    4.5771   4.56652   4.20651
# 2           2016   4.42959    4.3286   4.80279   4.57827   4.47377   4.31368
# 3           2015   4.23784   4.18233   4.00886    4.1291   4.35502   4.08396
# 4           2014   4.59758   4.28765   3.87335   4.33069   4.77958   3.88614
# 5           2013   3.84842   3.69499   3.56268   3.70872   3.86442   3.30489
# 6           2012   3.64909   3.87454   4.27002   3.97384   3.99186   4.20696
# 7           2011   3.59022   3.73375   3.42871   3.58949   3.66374    3.9073
# 8           2010   3.39947   3.17625   3.56015   3.39166   3.35944    3.3734
# 9           2009   1.64953   2.38358   3.35305   2.25375   3.08389   3.51442
# 10  Market year*       Jan       Feb       Mar        Q1       Apr       May
# ...

# %%
# review a section of the data
unit_price[11:21]
# Out:
#    Market year*       Jan       Feb       Mar        Q1       Apr       May  \
# 11         2018  0.504423   0.47714  0.405466  0.455794   0.37182  0.381589
# 12         2017  0.479338  0.479176  0.446754  0.467323  0.404915  0.405784
# 13         2016  0.542498  0.541151  0.521345  0.535976  0.485453  0.393829
# 14         2015  0.671185  0.716849  0.516797  0.612161  0.441585  0.390793
# 15         2014  0.497922  0.506943  0.456926    0.4837  0.425359  0.404841
# 16         2013   0.46301  0.459565  0.436259  0.450088  0.380057  0.381204
# 17         2012  0.481971  0.480582  0.401991  0.441942  0.363453  0.356037
# 18         2011  0.429915  0.439922  0.346986  0.394451  0.319569   0.32248
# 19         2010  0.383865  0.404605   0.39006  0.392513  0.343874  0.331856
# 20         2009   0.46691  0.435829  0.315747  0.376561  0.296991  0.320568
#
#          Jun        Q2       Jul       Aug       Sep        Q3       Oct  \
# ...

# %% [markdown]
# ## Working with Mango Data In Smaller Groups - Unit Price

# %%
# split up the overall data into smaller dataframes each representing each type of mango product and their unit prices over time
unit_price_dried, unit_price_fresh, unit_price_frozen, unit_price_juice, unit_price_prepared = pd.DataFrame(unit_price[:10]).reset_index().drop(['index'], axis=1), pd.DataFrame(unit_price[11:21]).reset_index().drop(['index'], axis=1), pd.DataFrame(unit_price[22:32]).reset_index().drop(['index'], axis=1), pd.DataFrame(unit_price[33:43]).reset_index().drop(['index'], axis=1), pd.DataFrame(unit_price[44:]).reset_index().drop(['index'], axis=1)

# %%
# sort values of the dried mango unit price data
unit_price_dried = unit_price_dried.sort_values('Market year*', ascending=True)

# %%
unit_price_dried
# Out:
#   Market year*      Jan      Feb      Mar       Q1      Apr      May      Jun  \
# 9         2009  1.64953  2.38358  3.35305  2.25375  3.08389  3.51442  3.44419
# 8         2010  3.39947  3.17625  3.56015  3.39166  3.35944   3.3734  3.59811
# 7         2011  3.59022  3.73375  3.42871  3.58949  3.66374   3.9073  4.15659
# 6         2012  3.64909  3.87454  4.27002  3.97384  3.99186  4.20696  3.94754
# 5         2013  3.84842  3.69499  3.56268  3.70872  3.86442  3.30489  4.21143
# 4         2014  4.59758  4.28765  3.87335  4.33069  4.77958  3.88614   4.2399
# 3         2015  4.23784  4.18233  4.00886   4.1291  4.35502  4.08396  4.15906
# 2         2016  4.42959   4.3286  4.80279  4.57827  4.47377  4.31368  4.42149
# 1         2017  5.13276  4.21988  4.51251   4.5771  4.56652  4.20651  4.16924
# 0         2018   4.1689  4.67385  4.42561  4.40594  4.18748  4.23262  4.03364
#
#         Q2      Jul      Aug      Sep       Q3      Oct      Nov      Dec  \
# ...

# %%
# plot the data to see the trend per year
unit_price_dried.plot(x='Market year*', y='Avg')

# %%
# sort values of the fresh mango unit price data
unit_price_fresh = unit_price_fresh.sort_values('Market year*', ascending=True)

# %%
unit_price_fresh
# Out:
#   Market year*       Jan       Feb       Mar        Q1       Apr       May  \
# 9         2009   0.46691  0.435829  0.315747  0.376561  0.296991  0.320568
# 8         2010  0.383865  0.404605   0.39006  0.392513  0.343874  0.331856
# 7         2011  0.429915  0.439922  0.346986  0.394451  0.319569   0.32248
# 6         2012  0.481971  0.480582  0.401991  0.441942  0.363453  0.356037
# 5         2013   0.46301  0.459565  0.436259  0.450088  0.380057  0.381204
# 4         2014  0.497922  0.506943  0.456926    0.4837  0.425359  0.404841
# 3         2015  0.671185  0.716849  0.516797  0.612161  0.441585  0.390793
# 2         2016  0.542498  0.541151  0.521345  0.535976  0.485453  0.393829
# 1         2017  0.479338  0.479176  0.446754  0.467323  0.404915  0.405784
# 0         2018  0.504423   0.47714  0.405466  0.455794   0.37182  0.381589
#
#         Jun        Q2       Jul       Aug       Sep        Q3       Oct  \
# ...

# %%
# plot the data to see the trend per year
unit_price_fresh.plot(x='Market year*', y='Avg')

# %%
# write to csv file
unit_price_fresh.to_csv('unit_price_fresh.csv')
unit_price_dried.to_csv('unit_price_dried.csv')

# %% [markdown]
# ## Overall USDA Mangos Import Data - Value

# %%
value = pd.read_excel('./data/Mangos_USDA_Data.xlsx', sheet_name = 'ImpValue', header = 3)

# %%
value.head()
# Out:
#    Unnamed: 0   NaN Dried Market year*      Jan      Feb      Mar        Q1  \
# 0         NaN  None  None         2018  7166713  6536541  7385904  21089158
# 1         NaN  None  None         2017  5709464  5622845  9929078  21261387
# 2         NaN  None  None         2016  3103997  3466454  6505382  13075833
# 3         NaN  None  None         2015  3690300  3524884  4652547  11867731
# 4         NaN  None  None         2014  4473211  3265081  1921737   9660029
#
#        Apr  None.1  ...        Q2       Jul       Aug       Sep        Q3  \
# 0  9005540     NaN  ...  39408582  16157334  16466129  14596203  47219666
# 1  7287586     NaN  ...  29541903  17336096  18346186  11833604  47515886
# 2  6430977     NaN  ...  23740206   9854508  14559061  10231695  34645264
# 3  7652350     NaN  ...  24457651  12791795  14853151   7453708  35098654
# 4  6253816     NaN  ...  16333103   6905901  11057531   6332761  24296193
#
#         Oct      Nov      Dec        Q4      Total
# ...

# %%
value.tail()
# Out:
#     Unnamed: 0                                                NaN Dried  \
# 52         NaN                                               None  None
# 53         NaN                                               None  None
# 54         NaN                                               None  None
# 55         NaN                                               None  None
# 56         NaN  Totals may not add due to rounding. Merchandis...  None
#
#    Market year*      Jan      Feb      Mar        Q1      Apr  None.1  ...  \
# 52         2010  3354895  3849623  4977742  12182260  6135881     NaN  ...
# 53         2009  3359754  3259514  4349640  10968908  4833658     NaN  ...
# 54         None     None     None     None      None     None     NaN  ...
# 55         None     None     None     None      None     None     NaN  ...
# 56         None     None     None     None      None     None     NaN  ...
#
#           Q2      Jul      Aug      Sep        Q3      Oct      Nov      Dec  \
# ...

# %%
value.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 23 columns):
# Unnamed: 0      0 non-null float64
# None            1 non-null object
# Dried           4 non-null object
# Market year*    54 non-null object
# Jan             51 non-null object
# Feb             51 non-null object
# Mar             51 non-null object
# Q1              51 non-null object
# Apr             51 non-null object
# None.1          0 non-null float64
# May             51 non-null object
# None.2          0 non-null float64
# Jun             51 non-null object
# Q2              51 non-null object
# Jul             52 non-null object
# Aug             52 non-null object
# Sep             52 non-null object
# Q3              52 non-null object
# Oct             52 non-null object
# Nov             52 non-null object
# Dec             52 non-null object
# Q4              52 non-null object
# Total           52 non-null object
# dtypes: float64(3), object(20)
# ...

# %%
# drop unnecessary columns
value = value.drop(['Unnamed: 0', 'Dried', None, 'None.1', 'None.2'], axis=1)

# %%
value.head()
# Out:
#   Market year*      Jan      Feb      Mar        Q1      Apr       May  \
# 0         2018  7166713  6536541  7385904  21089158  9005540  16223790
# 1         2017  5709464  5622845  9929078  21261387  7287586   9047645
# 2         2016  3103997  3466454  6505382  13075833  6430977   7945658
# 3         2015  3690300  3524884  4652547  11867731  7652350   5755098
# 4         2014  4473211  3265081  1921737   9660029  6253816   4237835
#
#         Jun        Q2       Jul       Aug       Sep        Q3       Oct  \
# 0  14179252  39408582  16157334  16466129  14596203  47219666  10479601
# 1  13206672  29541903  17336096  18346186  11833604  47515886  11780873
# 2   9363571  23740206   9854508  14559061  10231695  34645264   6685706
# 3  11050203  24457651  12791795  14853151   7453708  35098654   4062662
# 4   5841452  16333103   6905901  11057531   6332761  24296193   3563286
#
#        Nov      Dec        Q4      Total
# 0  8344888  5119684  23944173  131661579
# ...

# %%
value.tail()
# Out:
#    Market year*      Jan      Feb      Mar        Q1      Apr      May  \
# 52         2010  3354895  3849623  4977742  12182260  6135881  6434499
# 53         2009  3359754  3259514  4349640  10968908  4833658  5635080
# 54         None     None     None     None      None     None     None
# 55         None     None     None     None      None     None     None
# 56         None     None     None     None      None     None     None
#
#         Jun        Q2      Jul      Aug      Sep        Q3      Oct      Nov  \
# 52  7021858  19592238  8858863  7817418  6090452  22766733  3934815  4600789
# 53  6776312  17245050  7910738  8332840  5005223  21248801  4568570  3100778
# 54     None      None     None     None     None      None     None     None
# 55     None      None     None     None     None      None     None     None
# 56     None      None     None     None     None      None     None     None
#
#         Dec        Q4     Total
# 52  3049872  11585476  66126707
# ...

# %%
value.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 18 columns):
# Market year*    54 non-null object
# Jan             51 non-null object
# Feb             51 non-null object
# Mar             51 non-null object
# Q1              51 non-null object
# Apr             51 non-null object
# May             51 non-null object
# Jun             51 non-null object
# Q2              51 non-null object
# Jul             52 non-null object
# Aug             52 non-null object
# Sep             52 non-null object
# Q3              52 non-null object
# Oct             52 non-null object
# Nov             52 non-null object
# Dec             52 non-null object
# Q4              52 non-null object
# Total           52 non-null object
# dtypes: object(18)
# memory usage: 8.1+ KB

# %%
value = value.dropna(axis=0, how='any')

# %%
value.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 53
# Data columns (total 18 columns):
# Market year*    51 non-null object
# Jan             51 non-null object
# Feb             51 non-null object
# Mar             51 non-null object
# Q1              51 non-null object
# Apr             51 non-null object
# May             51 non-null object
# Jun             51 non-null object
# Q2              51 non-null object
# Jul             51 non-null object
# Aug             51 non-null object
# Sep             51 non-null object
# Q3              51 non-null object
# Oct             51 non-null object
# Nov             51 non-null object
# Dec             51 non-null object
# Q4              51 non-null object
# Total           51 non-null object
# dtypes: object(18)
# memory usage: 7.6+ KB

# %%
value['Market year*'].values
# Out:
# array(['2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011',
#        '2010', '2009', 'Market year*', '2018', '2017', '2016', '2015',
#        '2014', '2013', '2012', '2011', '2010', '2009', 'Market year*',
#        '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011',
#        '2010', '2009', 'Market year*', '2018', '2017', '2016', '2015',
#        '2014', '2013', '2012', 'Market year*', '2018', '2017', '2016',
#        '2015', '2014', '2013', '2012', '2011', '2010', '2009'],
#       dtype=object)

# %%
value[33:40]
# Out:
#    Market year*     Jan     Feb     Mar       Q1      Apr      May      Jun  \
# 33         2018  954699  651153  882135  2487987   841739  1144793  1421185
# 34         2017  783957  419410  898023  2101390  1096785  1024411  1366075
# 35         2016  471045  465646  720297  1656988   961459  1622227  1117851
# 36         2015  421834  499407  598602  1519843   625138   898258   930020
# 37         2014  411546  225295  802728  1439569   919347   654713   814714
# 38         2013  724176  468587  476801  1669564   482339   704317   515136
# 39         2012  409332  567863  355211  1332406   505102   690626   591517
#
#          Q2      Jul      Aug      Sep       Q3      Oct      Nov     Dec  \
# 33  3407717  1495628  1287131  1031191  3813950  1604233  1437491  972051
# 34  3487271  1141725  1160139  1106416  3408280   815810  1322536  746768
# 35  3701537   879054  1018212   718622  2615888   869868   585521  711862
# ...

# %%
# split up the overall data into smaller dataframes each representing each type of mango product and their unit prices over time
value_dried, value_fresh, value_frozen, value_juice, value_prepared = pd.DataFrame(value[:10]).reset_index().drop(['index'], axis=1), pd.DataFrame(value[11:21]).reset_index().drop(['index'], axis=1), pd.DataFrame(unit_price[22:32]).reset_index().drop(['index'], axis=1), pd.DataFrame(value[33:40]).reset_index().drop(['index'], axis=1), pd.DataFrame(value[41:]).reset_index().drop(['index'], axis=1)

# %%
value_dried
# Out:
#   Market year*      Jan      Feb      Mar        Q1      Apr       May  \
# 0         2018  7166713  6536541  7385904  21089158  9005540  16223790
# 1         2017  5709464  5622845  9929078  21261387  7287586   9047645
# 2         2016  3103997  3466454  6505382  13075833  6430977   7945658
# 3         2015  3690300  3524884  4652547  11867731  7652350   5755098
# 4         2014  4473211  3265081  1921737   9660029  6253816   4237835
# 5         2013  2946583  2202863  2409560   7559006  3561763   4138574
# 6         2012  2361779  4142978  4561009  11065766  2145617   3022237
# 7         2011  5100584  3066878  2548930  10716392  5019065   3553393
# 8         2010  2259712  2315889  3208849   7784450  2951978   4497872
# 9         2009  1357875   692553  1402029   3452457  2412823   5197063
#
#         Jun        Q2       Jul       Aug       Sep        Q3       Oct  \
# 0  14179252  39408582  16157334  16466129  14596203  47219666  10479601
# ...
